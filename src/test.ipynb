# %%
import networkx as nx
import matplotlib.pyplot as plt
from contextlib import redirect_stdin

# %%
with open("./data/test.txt") as f:
    with redirect_stdin(f):
        n, m, bat_cap, T = [int(i) for i in input().split()]

        build_cost, recharge, profit = [int(i) for i in input().split()]

        edge_list = [tuple([int(i) for i in input().split()]) for i in range(m)]

        demand = [int(i) for i in input().split()]


print(n, m, bat_cap, T)
print(build_cost, recharge, profit)
print(edge_list)
print(demand)
